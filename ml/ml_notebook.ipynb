# %% [markdown]
# # СберАвтоподписка - ML Engineer
#
# ## Предиктивная модель

# %%
import pickle
import pandas as pd
from sklearn.metrics import roc_auc_score
print('ML model loaded. See ml_model_fast.py for training code')

# %% [markdown]
# ## API сервис

# %%
# See ml_api.py for Flask API
